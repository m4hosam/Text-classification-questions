# %%
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# nltk.download("wordnet")
# nltk.download("omw-1.4")

# Initialize wordnet lemmatizer, stopwords and punkt
wnl = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
punkt = nltk.RegexpTokenizer(r"\w+")

# %%
original_text = """In computer architecture, multithreading is
                the ability of a central processing unit (CPU)
                (or a single core in a multi-core processor) to 
                provide multiple threads of execution concurrently,
                supported by the operating system. This approach
                differs from multiprocessing. In a multithreaded
                application, the threads share the resources of
                a single or multiple cores, which include the
                computing units, the CPU caches, and the 
                translation lookaside buffer (TLB)."""

candidate_labels = ['Programming', 'Math', 'Psychology', 'Geology']

# %% [markdown]
# Preprocessing the text and removing punk.

# %%
def preprocess(text):
    # Tokenization using Regex Tokenizer
    tokens = punkt.tokenize(text)
    
    # Lowercasing
    tokens = [token.lower() for token in tokens]
    
    # Stopword removal
    tokens = [token for token in tokens if token not in stop_words]

    # lemmatization
    tokens = [wnl.lemmatize(token) for token in tokens]
    
    return tokens

preprocess(original_text)

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                    model="facebook/bart-large-mnli")

# %%
classifier(original_text, candidate_labels)
# Out:
# [{'sequence': 'computer',
#   'labels': ['Programming', 'Math', 'Psychology', 'Geology'],
#   'scores': [0.7000942230224609,
#    0.16895438730716705,
#    0.08026382327079773,
#    0.05068760737776756]},
#  {'sequence': 'architecture',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.40137338638305664,
#    0.20803514122962952,
#    0.19760528206825256,
#    0.19298622012138367]},
#  {'sequence': 'multithreading',
#   'labels': ['Programming', 'Math', 'Psychology', 'Geology'],
#   'scores': [0.3192826211452484,
#    0.27229663729667664,
#    0.21526646614074707,
#    0.19315433502197266]},
#  {'sequence': 'ability',
#   'labels': ['Programming', 'Geology', 'Math', 'Psychology'],
#   'scores': [0.35780227184295654,
#    0.2189551293849945,
#    0.2177664041519165,
#    0.20547610521316528]},
#  {'sequence': 'central',
#   'labels': ['Programming', 'Geology', 'Psychology', 'Math'],
#   'scores': [0.32331427931785583,
#    0.31515973806381226,
#    0.18412598967552185,
#    0.17740005254745483]},
#  {'sequence': 'processing',
#   'labels': ['Programming', 'Psychology', 'Math', 'Geology'],
#   'scores': [0.7767037749290466,
#    0.10711435228586197,
#    0.06649934500455856,
#    0.04968256503343582]},
#  {'sequence': 'unit',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.41223031282424927,
#    0.3298727869987488,
#    0.1442032903432846,
#    0.11369363963603973]},
#  {'sequence': 'cpu',
#   'labels': ['Programming', 'Math', 'Psychology', 'Geology'],
#   'scores': [0.8472188711166382,
#    0.08595453947782516,
#    0.03464042767882347,
#    0.03218614682555199]},
#  {'sequence': 'single',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.35936206579208374,
#    0.23977778851985931,
#    0.20575527846813202,
#    0.19510476291179657]},
#  {'sequence': 'core',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.36745259165763855,
#    0.2470628321170807,
#    0.24143047630786896,
#    0.1440541297197342]},
#  {'sequence': 'multi',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.3280739188194275,
#    0.2925039231777191,
#    0.2067842334508896,
#    0.1726379245519638]},
#  {'sequence': 'core',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.36745259165763855,
#    0.2470628321170807,
#    0.24143047630786896,
#    0.1440541297197342]},
#  {'sequence': 'processor',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.9138930439949036,
#    0.03521927818655968,
#    0.02659343183040619,
#    0.024294273927807808]},
#  {'sequence': 'provide',
#   'labels': ['Programming', 'Geology', 'Psychology', 'Math'],
#   'scores': [0.41916170716285706,
#    0.2368786484003067,
#    0.17822270095348358,
#    0.16573692858219147]},
#  {'sequence': 'multiple',
#   'labels': ['Math', 'Programming', 'Geology', 'Psychology'],
#   'scores': [0.33663180470466614,
#    0.2614442706108093,
#    0.21563570201396942,
#    0.18628817796707153]},
#  {'sequence': 'thread',
#   'labels': ['Programming', 'Geology', 'Psychology', 'Math'],
#   'scores': [0.37226319313049316,
#    0.22570110857486725,
#    0.2122555822134018,
#    0.18978014588356018]},
#  {'sequence': 'execution',
#   'labels': ['Programming', 'Psychology', 'Math', 'Geology'],
#   'scores': [0.46009618043899536,
#    0.22449173033237457,
#    0.1748015582561493,
#    0.1406105011701584]},
#  {'sequence': 'concurrently',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.34858986735343933,
#    0.22967609763145447,
#    0.21296879649162292,
#    0.20876522362232208]},
#  {'sequence': 'supported',
#   'labels': ['Programming', 'Geology', 'Psychology', 'Math'],
#   'scores': [0.35252583026885986,
#    0.23495788872241974,
#    0.2105145901441574,
#    0.20200175046920776]},
#  {'sequence': 'operating',
#   'labels': ['Programming', 'Math', 'Psychology', 'Geology'],
#   'scores': [0.8881965279579163,
#    0.04338868334889412,
#    0.036175161600112915,
#    0.032239582389593124]},
#  {'sequence': 'system',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.3984285593032837,
#    0.22238671779632568,
#    0.19716961681842804,
#    0.18201512098312378]},
#  {'sequence': 'approach',
#   'labels': ['Programming', 'Psychology', 'Geology', 'Math'],
#   'scores': [0.33281663060188293,
#    0.24301926791667938,
#    0.22607241570949554,
#    0.19809171557426453]},
#  {'sequence': 'differs',
#   'labels': ['Math', 'Geology', 'Programming', 'Psychology'],
#   'scores': [0.29393666982650757,
#    0.29333627223968506,
#    0.22088539600372314,
#    0.19184161722660065]},
#  {'sequence': 'multiprocessing',
#   'labels': ['Programming', 'Math', 'Psychology', 'Geology'],
#   'scores': [0.3845914304256439,
#    0.30518895387649536,
#    0.16199597716331482,
#    0.14822357892990112]},
#  {'sequence': 'multithreaded',
#   'labels': ['Programming', 'Psychology', 'Geology', 'Math'],
#   'scores': [0.4413596987724304,
#    0.2055237591266632,
#    0.18042272329330444,
#    0.17269383370876312]},
#  {'sequence': 'application',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.3383388817310333,
#    0.23340186476707458,
#    0.22002020478248596,
#    0.20823907852172852]},
#  {'sequence': 'thread',
#   'labels': ['Programming', 'Geology', 'Psychology', 'Math'],
#   'scores': [0.37226319313049316,
#    0.22570110857486725,
#    0.2122555822134018,
#    0.18978014588356018]},
#  {'sequence': 'share',
#   'labels': ['Programming', 'Geology', 'Psychology', 'Math'],
#   'scores': [0.32310739159584045,
#    0.2627100348472595,
#    0.21604278683662415,
#    0.19813978672027588]},
#  {'sequence': 'resource',
#   'labels': ['Programming', 'Geology', 'Math', 'Psychology'],
#   'scores': [0.3151308000087738,
#    0.3133050501346588,
#    0.19174394011497498,
#    0.17982028424739838]},
#  {'sequence': 'single',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.35936206579208374,
#    0.23977778851985931,
#    0.20575527846813202,
#    0.19510476291179657]},
#  {'sequence': 'multiple',
#   'labels': ['Math', 'Programming', 'Geology', 'Psychology'],
#   'scores': [0.33663180470466614,
#    0.2614442706108093,
#    0.21563570201396942,
#    0.18628817796707153]},
#  {'sequence': 'core',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.36745259165763855,
#    0.2470628321170807,
#    0.24143047630786896,
#    0.1440541297197342]},
#  {'sequence': 'include',
#   'labels': ['Programming', 'Geology', 'Math', 'Psychology'],
#   'scores': [0.36565515398979187,
#    0.24705789983272552,
#    0.203704833984375,
#    0.18358217179775238]},
#  {'sequence': 'computing',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.6015042662620544,
#    0.36671459674835205,
#    0.016068657860159874,
#    0.01571245864033699]},
#  {'sequence': 'unit',
#   'labels': ['Programming', 'Math', 'Geology', 'Psychology'],
#   'scores': [0.41223031282424927,
#    0.3298727869987488,
#    0.1442032903432846,
#    0.11369363963603973]},
#  {'sequence': 'cpu',
#   'labels': ['Programming', 'Math', 'Psychology', 'Geology'],
#   'scores': [0.8472188711166382,
#    0.08595453947782516,
#    0.03464042767882347,
#    0.03218614682555199]},
#  {'sequence': 'cache',
#   'labels': ['Programming', 'Geology', 'Math', 'Psychology'],
#   'scores': [0.3470526933670044,
#    0.25902289152145386,
#    0.20814049243927002,
#    0.18578390777111053]},
#  {'sequence': 'translation',
#   'labels': ['Geology', 'Psychology', 'Programming', 'Math'],
#   'scores': [0.27231839299201965,
#    0.26554179191589355,
#    0.25592777132987976,
#    0.20621202886104584]},
#  {'sequence': 'lookaside',
#   'labels': ['Psychology', 'Geology', 'Programming', 'Math'],
#   'scores': [0.29398810863494873,
#    0.27731853723526,
#    0.23329474031925201,
#    0.19539867341518402]},
#  {'sequence': 'buffer',
#   'labels': ['Programming', 'Geology', 'Math', 'Psychology'],
#   'scores': [0.365648090839386,
#    0.23038256168365479,
#    0.2166905403137207,
#    0.18727876245975494]},
#  {'sequence': 'tlb',
#   'labels': ['Programming', 'Geology', 'Psychology', 'Math'],
#   'scores': [0.3693094551563263,
#    0.21805694699287415,
#    0.20633353292942047,
#    0.2063000500202179]}]
